# %%
from fastai.vision import *

# %%
path = untar_data(URLs.CAMVID)

# %%
path.ls()
# Out:
# [PosixPath('/root/.fastai/data/camvid/valid.txt'),
#  PosixPath('/root/.fastai/data/camvid/labels'),
#  PosixPath('/root/.fastai/data/camvid/images'),
#  PosixPath('/root/.fastai/data/camvid/codes.txt')]

# %%
path_img=path/'images'
path_lbl=path/'labels'

# %%
path_img.ls()
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0016E5_00690.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_08061.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_009900.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_007170.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_07971.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f04320.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_07020.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f03180.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f04230.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_00901.png'),
#  PosixPath('/root/.fastai/data/camvid/images/Seq05VD_f04950.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_08077.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0006R0_f01020.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_008490.png'),
# ...

# %%
imagesNames=get_image_files(path_img)
imagesNames[:5]
# Out:
# [PosixPath('/root/.fastai/data/camvid/images/0016E5_00690.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_08061.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_009900.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0001TP_007170.png'),
#  PosixPath('/root/.fastai/data/camvid/images/0016E5_07971.png')]

# %%
labelNames=get_image_files(path_lbl)

# %%
labelNames[:5]
# Out:
# [PosixPath('/root/.fastai/data/camvid/labels/Seq05VD_f01320_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_01980_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_07965_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_07997_P.png'),
#  PosixPath('/root/.fastai/data/camvid/labels/0016E5_05880_P.png')]

# %%
get_label_image= lambda x: path_lbl/f'{x.stem}_P{x.suffix}'

# %%
image6path=imagesNames[6]

# %%
#img=imagesNames[6]
img=open_image(image6path)
img.show(figsize=(8,8))

# %%
label = open_image(get_label_image(imagesNames[6]))
label.show(figsize=(8,8))

# %%
label_img_path=get_label_image(imagesNames[6])

# %%
mask=open_mask(get_label_image(imagesNames[6]))
mask.show(figsize=(8,8))

# %%
mask.data
# Out:
# tensor([[[ 4,  4,  4,  ...,  4,  4,  4],
#          [ 4,  4,  4,  ...,  4,  4,  4],
#          [ 4,  4,  4,  ...,  4,  4,  4],
#          ...,
#          [19, 19, 19,  ..., 17, 17, 17],
#          [19, 19, 19,  ..., 17, 17, 17],
#          [19, 19, 19,  ..., 17, 17, 17]]])

# %%
img.data[-1,-1,-1]
# Out:
# tensor(0.2353)

# %%
mask.data[-1,-1,-1]
# Out:
# tensor(17)

# %%
codes = np.loadtxt(path/'codes.txt', dtype='str'); codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole',
#        'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter', 'OtherMoving', 'ParkingBlock',
#        'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone',
#        'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel', 'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
label.data[1,6,469]
# Out:
# tensor(0.0824)
